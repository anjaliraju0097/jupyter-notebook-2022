# %%
import pandas as pd

# %%
df=pd.read_csv("wine.csv")

# %%
df
# Out:
#        country                               designation  points  price  \
# 0    Argentina                                       NaN      85   12.0
# 1      Germany  Piesporter Goldtröpfchen Auslese Goldkap      92   48.0
# 2        Spain                               Bla Bla Bla      83   15.0
# 3       Canada                                       NaN      85   12.0
# 4           US                       Sierra Mar Vineyard      86   55.0
# ..         ...                                       ...     ...    ...
# 495         US                                       NaN      87    9.0
# 496         US                                   Drizzle      91   17.0
# 497     France                                   Réserve      93   35.0
# 498      Italy                                   Passión      88   25.0
# 499   Portugal                     Vertice Cuvée Reserva      87   19.0
#
#                province                    region_1         region_2  \
# ...

# %%
df.shape #display no of rows and columns
# Out:
# (500, 9)

# %%
df[:6] #display 1st 5 rows
# Out:
#      country                               designation  points  price  \
# 0  Argentina                                       NaN      85   12.0
# 1    Germany  Piesporter Goldtröpfchen Auslese Goldkap      92   48.0
# 2      Spain                               Bla Bla Bla      83   15.0
# 3     Canada                                       NaN      85   12.0
# 4         US                       Sierra Mar Vineyard      86   55.0
# 5  Argentina                              Seleccionada      86   18.0
#
#            province                 region_1       region_2     variety  \
# 0             Other          Famatina Valley            NaN      Malbec
# 1  Mosel-Saar-Ruwer                      NaN            NaN    Riesling
# 2   Spanish Islands  Vi de la Terra Mallorca            NaN     Premsal
# 3           Ontario        Niagara Peninsula            NaN    Riesling
# 4        California    Santa Lucia Highlands  Central Coast  Pinot Noir
# ...

# %%
df[497:] #display last 3 rows
# Out:
#       country            designation  points  price            province  \
# 497    France                Réserve      93   35.0              Alsace
# 498     Italy                Passión      88   25.0  Northeastern Italy
# 499  Portugal  Vertice Cuvée Reserva      87   19.0               Douro
#
#                        region_1 region_2               variety  \
# 497                      Alsace      NaN              Riesling
# 498  Colli Orientali del Friuli      NaN           White Blend
# 499                         NaN      NaN  Portuguese Sparkling
#
#                   winery
# 497             Trimbach
# 498        Guerra Albano
# 499  Caves Transmontanas

# %%
df.columns #display all the columns
# Out:
# Index(['country', 'designation', 'points', 'price', 'province', 'region_1',
#        'region_2', 'variety', 'winery'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=500, step=1)

# %%
df.describe(include="all") #inludes most of the columns
# Out:
#        country designation      points       price    province     region_1  \
# count      500         343  500.000000  462.000000         500          420
# unique      21         306         NaN         NaN          86          190
# top         US     Reserve         NaN         NaN  California  Napa Valley
# freq       208          17         NaN         NaN         142           23
# mean       NaN         NaN   87.760000   31.257576         NaN          NaN
# std        NaN         NaN    3.237803   29.443661         NaN          NaN
# min        NaN         NaN   80.000000    6.000000         NaN          NaN
# 25%        NaN         NaN   85.000000   15.000000         NaN          NaN
# 50%        NaN         NaN   87.000000   22.000000         NaN          NaN
# 75%        NaN         NaN   90.000000   39.750000         NaN          NaN
# max        NaN         NaN   96.000000  275.000000         NaN          NaN
#
#              region_2     variety winery
# ...

# %%
df['price'].mean() #finds the mean of the column
# Out:
# 31.257575757575758

# %%
df['country'].value_counts() #finds the cound of the column
# Out:
# US              208
# France           74
# Italy            73
# Spain            25
# Argentina        22
# Portugal         19
# Chile            18
# New Zealand      18
# Australia        16
# South Africa      6
# Germany           5
# Austria           4
# Canada            2
# Greece            2
# Israel            2
# Romania           1
# Lithuania         1
# South Korea       1
# Uruguay           1
# Turkey            1
# Hungary           1
# Name: country, dtype: int64

# %%
df[df['points']>85]
# Out:
#        country                               designation  points  price  \
# 1      Germany  Piesporter Goldtröpfchen Auslese Goldkap      92   48.0
# 4           US                       Sierra Mar Vineyard      86   55.0
# 5    Argentina                              Seleccionada      86   18.0
# 7        Italy                                       NaN      89   23.0
# 8      Germany               Ürziger Würzgarten Kabinett      89   19.0
# ..         ...                                       ...     ...    ...
# 495         US                                       NaN      87    9.0
# 496         US                                   Drizzle      91   17.0
# 497     France                                   Réserve      93   35.0
# 498      Italy                                   Passión      88   25.0
# 499   Portugal                     Vertice Cuvée Reserva      87   19.0
#
#                province                    region_1         region_2  \
# ...

# %%
df[df['price']>50]
# Out:
#        country                                     designation  points  price  \
# 4           US                             Sierra Mar Vineyard      86   55.0
# 27          US                                             NaN      93  125.0
# 32    Portugal                   Duas Quintas Reserva Especial      93   67.0
# 33      France                              Cuvée Hyménée Brut      90   89.0
# 42      France                                             NaN      94  130.0
# 48          US                                         Melbury      95  225.0
# 66      France                                 Vieilles Vignes      89  261.0
# 73   Argentina                      Bramare Marchiori Vineyard      91   80.0
# 75          US                                             NaN      87   65.0
# 83       Italy                                           Madre      91   76.0
# 84      France                                 Vieilles Vignes      90   55.0
# ...

# %%
df['region_2'].value_counts()
# Out:
# Central Coast              47
# Sonoma                     37
# Columbia Valley            33
# Napa                       32
# California Other            9
# Willamette Valley           9
# Finger Lakes                6
# Long Island                 5
# Oregon Other                5
# Central Valley              4
# Napa-Sonoma                 4
# Mendocino/Lake Counties     4
# Sierra Foothills            3
# North Coast                 2
# Washington Other            2
# Southern Oregon             2
# Name: region_2, dtype: int64

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv("wine.csv")
df
# Out:
#        country                               designation  points  price  \
# 0    Argentina                                       NaN      85   12.0
# 1      Germany  Piesporter Goldtröpfchen Auslese Goldkap      92   48.0
# 2        Spain                               Bla Bla Bla      83   15.0
# 3       Canada                                       NaN      85   12.0
# 4           US                       Sierra Mar Vineyard      86   55.0
# ..         ...                                       ...     ...    ...
# 495         US                                       NaN      87    9.0
# 496         US                                   Drizzle      91   17.0
# 497     France                                   Réserve      93   35.0
# 498      Italy                                   Passión      88   25.0
# 499   Portugal                     Vertice Cuvée Reserva      87   19.0
#
#                province                    region_1         region_2  \
# ...

# %%
x=np.arange(40,50)
y=np.arange(50.60)
plt.scatter(x='price',y='point')
plt.xlabel('Xaxis')
plt.ylabel('Yaxis')
plt.legend(['a sample line'])
plt.show()

# %% [markdown]
# using seaborn:
# scatter plot of 2 number plots

# %%
sns.scatterplot(x='points',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='points', ylabel='price'>

# %%
df.region_1.value_counts().plot(kind='bar',rot='0')

plt.show()

# %%
df.winery.value_counts().plot(kind='bar',rot='0')

plt.show()

# %%
df.country.value_counts().plot(kind='bar',rot='0')

plt.show()

# %%
df.region_2.value_counts().plot(kind='bar',rot='0')
plt.show()

# %%
df1=pd.read_csv('titanic.csv')
df1
# Out:
#     Passenger_No first_name    last_name  survived  pclass     sex  age  \
# 0              1     Steven         King         0       3    male   22
# 1              2       Ross      Kochhar         1       1  female   38
# 2              3       Alex        Urman         1       3  female   26
# 3              4      Bruce         Popp         1       1  female   35
# 4              5      David     Raphaely         0       3    male   35
# 5              6      Nancy         Khoo         0       3    male   27
# 6              7       John        Baida         0       1    male   54
# 7              8     Daniel        Weiss         0       3    male    2
# 8              9      Sigal     Kaufling         1       3  female   27
# 9             10       Adam      Vollman         1       2  female   14
# 10            11     Mathew       Himuro         1       3  female    4
# 11            12     Harvey  Mikkilineni         1       1  female   58
# ...

# %%
r=df1['class'].value_counts()
r
import matplotlib.pyplot as plt
plt.pie(r,radius=1.2,labels=['First','Second','Third'])
plt.show()

# %%
ax=sns.boxplot(x=df['price'],orient='h')

# %%
sns.scatterplot(x='pclass',y='age',data=df1)
plt.show()

# %%
df1.survived.value_counts().plot(kind='bar',rot='0')
plt.show()

# %%
df1.embarked.value_counts().plot(kind='bar',rot='0')
plt.show()
