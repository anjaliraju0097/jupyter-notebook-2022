# %%
import numpy as np

# %%
n1=np.random.randint(100,size=(3,4))

# %%
n1

# %%
np.random.seed(22)

# %%
np.zeros(shape=(3,4))

# %%
##pandas--used to examine data

# %%
import pandas as pd

# %%
#pandas data manupulation and analysis
#missing data,flexible reshaping,outlier--(find out the data which is flexible for our need and found out the unusal abnormal thing)

# %%
#--2 types of datastructures
#1)series-- 1D array which is capable of holding any datatype
#2)dataframe

# %%
#1)series-- 1D array which is capable of holding any datatype
l1=[10,34,'erty',34]

# %%
s1=pd.Series(l1)
s1
# Out:
# 0      10
# 1      34
# 2    erty
# 3      34
# dtype: object

# %%
l2=[100,200,300]

# %%
s1=pd.Series(l2) #the int64 shows all are integers
s1
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
s1.index #automated index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
l3=[100,200,300,400]

# %%
s2=pd.Series(l3,index=['tata','birla','RIL','BEL'])

# %%
s2
# Out:
# tata     100
# birla    200
# RIL      300
# BEL      400
# dtype: int64

# %%
l4=[78,50,67,90]

# %%
s3=pd.Series(l4,index=['Anjali','Anjana','Saliha','Muhsina'])
s3
# Out:
# Anjali     30
# Anjana     50
# Saliha     67
# Muhsina    90
# dtype: int64

# %%
s3.dtype
# Out:
# dtype('int64')

# %%
s3.index
# Out:
# Index(['Anjali', 'Anjana', 'Saliha', 'Muhsina'], dtype='object')

# %%
s3.describe()
# Out:
# count     4.000000
# mean     59.250000
# std      25.473843
# min      30.000000
# 25%      45.000000
# 50%      58.500000
# 75%      72.750000
# max      90.000000
# dtype: float64

# %%
s1
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
s2[0]
# Out:
# 100

# %%
s3[1:4]
# Out:
# Anjana     50
# Saliha     67
# Muhsina    90
# dtype: int64

# %%
s3['Anjali':'Muhsina']
# Out:
# Anjali     30
# Anjana     50
# Saliha     67
# Muhsina    90
# dtype: int64

# %%
#conditiob
s2[s2>250]
# Out:
# RIL    300
# BEL    400
# dtype: int64

# %%
s2[(s2>150) & (s2<250)]
# Out:
# birla    200
# dtype: int64

# %%
price=[250,350,275]

# %%
s4=pd.Series(price,index=['chees','spicyChicken','vegPaneer'])
s4
# Out:
# chees           250
# spicyChicken    350
# vegPaneer       275
# dtype: int64

# %%
s4.index
# Out:
# Index(['chees', 'spicyChicken', 'vegPaneer'], dtype='object')

# %%
s4[s4>300]
# Out:
# spicyChicken    350
# dtype: int64

# %%
#2)Dataframe

# %%
rp2={'Location':['Bangalore','Cochin'],
'Jan':[100,500]} #creating a data dictionary

# %%
rp2
# Out:
# {'Location': ['Bangalore', 'Cochin'], 'Jan': [100, 500]}

# %%
df=pd.DataFrame(rp2)

# %%
df
# Out:
#     Location  Jan
# 0  Bangalore  100
# 1     Cochin  500

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
df.columns
# Out:
# Index(['Location', 'Jan'], dtype='object')

# %%
#df.to_csv("salary.csv")

# %%
df={'':['Retail','Banking','Tech','Transport'],
    'Tata':[100,200,300,400,],
'Birla':[500,600,700,800]} 
df
# Out:
# {'': ['Retail', 'Banking', 'Tech', 'Transport'],
#  'Tata': [100, 200, 300, 400],
#  'Birla': [500, 600, 700, 800]}

# %%
df1=pd.DataFrame(df)
df1
# Out:
#               Tata  Birla
# 0     Retail   100    500
# 1    Banking   200    600
# 2       Tech   300    700
# 3  Transport   400    800

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df1.columns
# Out:
# Index(['', 'Tata', 'Birla'], dtype='object')

# %%
df1.shape
# Out:
# (4, 3)

# %%
df1.ndim
# Out:
# 2

# %%
df1.describe()
# Out:
#              Tata       Birla
# count    4.000000    4.000000
# mean   250.000000  650.000000
# std    129.099445  129.099445
# min    100.000000  500.000000
# 25%    175.000000  575.000000
# 50%    250.000000  650.000000
# 75%    325.000000  725.000000
# max    400.000000  800.000000

# %%
df3=pd.read_csv("profit1.csv")

# %%
df3
# Out:
#           Vol    Rev  Exp Catg  EmpCnt   HQ
# HCL       931  863.5  605  Pub    1935  NCR
# MRF       992  821.0  665  Pub    1154  Che
# ISROACL   931  881.6  650  Gov    1361  Blr
# Reliance  899  917.0  674  Pub    1443  Mum
# BCCI      925  839.8  615  Pvt     154  Mum
# Birla     900  874.4  676  Pub    1379  Kol
# Flipkart  966  805.0  895  Pvt     119  Blr
# Apollo    966  863.2  608  Pub    1656  Che
# IR        954  733.0  609  Gov   13023  NCR

# %%
import pandas as pd

# %%
df3=pd.read_csv("profit1.csv")

# %%
df3
# Out:
#           Vol    Rev  Exp Catg  EmpCnt   HQ
# HCL       931  863.5  605  Pub    1935  NCR
# MRF       992  821.0  665  Pub    1154  Che
# ISROACL   931  881.6  650  Gov    1361  Blr
# Reliance  899  917.0  674  Pub    1443  Mum
# BCCI      925  839.8  615  Pvt     154  Mum
# Birla     900  874.4  676  Pub    1379  Kol
# Flipkart  966  805.0  895  Pvt     119  Blr
# Apollo    966  863.2  608  Pub    1656  Che
# IR        954  733.0  609  Gov   13023  NCR

# %%
df3.describe()
# Out:
#               Vol         Rev         Exp        EmpCnt
# count    9.000000    9.000000    9.000000      9.000000
# mean   940.444444  844.277778  666.333333   2469.333333
# std     31.460734   53.389788   90.689029   4006.439036
# min    899.000000  733.000000  605.000000    119.000000
# 25%    925.000000  821.000000  609.000000   1154.000000
# 50%    931.000000  863.200000  650.000000   1379.000000
# 75%    966.000000  874.400000  674.000000   1656.000000
# max    992.000000  917.000000  895.000000  13023.000000

# %%
df3.shape
# Out:
# (9, 6)

# %%
df3[df3['Exp']<689]
# Out:
#           Vol    Rev  Exp Catg  EmpCnt   HQ
# HCL       931  863.5  605  Pub    1935  NCR
# MRF       992  821.0  665  Pub    1154  Che
# ISROACL   931  881.6  650  Gov    1361  Blr
# Reliance  899  917.0  674  Pub    1443  Mum
# BCCI      925  839.8  615  Pvt     154  Mum
# Birla     900  874.4  676  Pub    1379  Kol
# Apollo    966  863.2  608  Pub    1656  Che
# IR        954  733.0  609  Gov   13023  NCR

# %%
df3['Exp']
# Out:
# HCL         605
# MRF         665
# ISROACL     650
# Reliance    674
# BCCI        615
# Birla       676
# Flipkart    895
# Apollo      608
# IR          609
# Name: Exp, dtype: int64

# %%
df7=pd.read_csv("titanic.csv")

# %%
df7
# Out:
#     Passenger_No first_name    last_name  survived  pclass     sex  age  \
# 0              1     Steven         King         0       3    male   22
# 1              2       Ross      Kochhar         1       1  female   38
# 2              3       Alex        Urman         1       3  female   26
# 3              4      Bruce         Popp         1       1  female   35
# 4              5      David     Raphaely         0       3    male   35
# 5              6      Nancy         Khoo         0       3    male   27
# 6              7       John        Baida         0       1    male   54
# 7              8     Daniel        Weiss         0       3    male    2
# 8              9      Sigal     Kaufling         1       3  female   27
# 9             10       Adam      Vollman         1       2  female   14
# 10            11     Mathew       Himuro         1       3  female    4
# 11            12     Harvey  Mikkilineni         1       1  female   58
# 12            13      Kevin       Rogers         0       3    male   20
# 13            14      Julia        Patel         0       3    male   39
# 14            15      Irene       Davies         0       3  female   14
# 15            16      James      Zlotkey         1       2  female   55
# 16            17      Jason    Bernstein         0       3    male    2
# 17            18      Peter         Hall         1       2    male   34
# 18            19     Sartha        Sully         0       3  female   31
# 19            20    William        Smith         1       3  female   29
# 20            21       Jack       Greene         0       2    male   35
#
#     parch   fare embarked   class    who  adult_male deck  embark_town alive  \
# 0       0  24000        S   Third    man        True    A  Southampton    no
# 1       0  50806        C   First  woman       False    C    Cherbourg   yes
# 2       0  54071        S   Third  woman       False    B  Southampton   yes
# 3       0  26969        S   First  woman       False    C  Southampton   yes
# 4       0  34048        S   Third    man        True    C  Southampton    no
# 5       0  46206        Q   Third    man        True    E   Queenstown    no
# 6       0  63090        S   First    man        True    E  Southampton    no
# 7       1  56356        S   Third  child       False    G  Southampton    no
# 8       2  23488        S   Third  woman       False    A  Southampton   yes
# 9       0  29047        C  Second  child       False    B    Cherbourg   yes
# 10      1  51428        S   Third  child       False    G  Southampton   yes
# 11      0  61770        S   First  woman       False    C  Southampton   yes
# 12      0  30897        S   Third    man        True    C  Southampton    no
# 13      5  59197        S   Third    man        True    C  Southampton    no
# 14      0  61211        S   Third  child       False    G  Southampton    no
# 15      0  43386        S  Second  woman       False    D  Southampton   yes
# 16      1  27978        Q   Third  child       False    G   Queenstown    no
# 17      0  46632        S  Second    man        True    B  Southampton   yes
# 18      0  66662        S   Third  woman       False    D  Southampton    no
# 19      0  38628        C   Third  woman       False    D    Cherbourg   yes
# 20      0  20068        S  Second    man        True    G  Southampton    no
#
#     alone  DECK_NUMBER
# 0   False           90
# 1   False           90
# 2    True           90
# 3   False           60
# 4    True           60
# 5    True           70
# 6    True           70
# 7   False           70
# 8   False           60
# 9   False           90
# 10  False          100
# 11   True          100
# 12   True           70
# 13  False           80
# 14   True           80
# 15   True           80
# 16  False          100
# 17   True           80
# 18  False           60
# 19   True           70
# 20   True           90

# %%
df7.shape
# Out:
# (21, 18)

# %%
df7.describe()
# Out:
#        Passenger_No   survived     pclass        age      parch          fare  \
# count     21.000000  21.000000  21.000000  21.000000  21.000000     21.000000
# mean      11.000000   0.476190   2.428571  28.619048   0.476190  43616.095238
# std        6.204837   0.511766   0.810643  16.026466   1.167007  15081.489823
# min        1.000000   0.000000   1.000000   2.000000   0.000000  20068.000000
# 25%        6.000000   0.000000   2.000000  20.000000   0.000000  29047.000000
# 50%       11.000000   0.000000   3.000000  29.000000   0.000000  46206.000000
# 75%       16.000000   1.000000   3.000000  35.000000   0.000000  56356.000000
# max       21.000000   1.000000   3.000000  58.000000   5.000000  66662.000000
#
#        DECK_NUMBER
# count    21.000000
# mean     79.047619
# std      13.749459
# min      60.000000
# 25%      70.000000
# 50%      80.000000
# 75%      90.000000
# max     100.000000

# %%
df7[:11]
# Out:
#     Passenger_No first_name last_name  survived  pclass     sex  age  parch  \
# 0              1     Steven      King         0       3    male   22      0
# 1              2       Ross   Kochhar         1       1  female   38      0
# 2              3       Alex     Urman         1       3  female   26      0
# 3              4      Bruce      Popp         1       1  female   35      0
# 4              5      David  Raphaely         0       3    male   35      0
# 5              6      Nancy      Khoo         0       3    male   27      0
# 6              7       John     Baida         0       1    male   54      0
# 7              8     Daniel     Weiss         0       3    male    2      1
# 8              9      Sigal  Kaufling         1       3  female   27      2
# 9             10       Adam   Vollman         1       2  female   14      0
# 10            11     Mathew    Himuro         1       3  female    4      1
#
#      fare embarked   class    who  adult_male deck  embark_town alive  alone  \
# 0   24000        S   Third    man        True    A  Southampton    no  False
# 1   50806        C   First  woman       False    C    Cherbourg   yes  False
# 2   54071        S   Third  woman       False    B  Southampton   yes   True
# 3   26969        S   First  woman       False    C  Southampton   yes  False
# 4   34048        S   Third    man        True    C  Southampton    no   True
# 5   46206        Q   Third    man        True    E   Queenstown    no   True
# 6   63090        S   First    man        True    E  Southampton    no   True
# 7   56356        S   Third  child       False    G  Southampton    no  False
# 8   23488        S   Third  woman       False    A  Southampton   yes  False
# 9   29047        C  Second  child       False    B    Cherbourg   yes  False
# 10  51428        S   Third  child       False    G  Southampton   yes  False
#
#     DECK_NUMBER
# 0            90
# 1            90
# 2            90
# 3            60
# 4            60
# 5            70
# 6            70
# 7            70
# 8            60
# 9            90
# 10          100

# %%
df7['fare']
# Out:
# 0     24000
# 1     50806
# 2     54071
# 3     26969
# 4     34048
# 5     46206
# 6     63090
# 7     56356
# 8     23488
# 9     29047
# 10    51428
# 11    61770
# 12    30897
# 13    59197
# 14    61211
# 15    43386
# 16    27978
# 17    46632
# 18    66662
# 19    38628
# 20    20068
# Name: fare, dtype: int64

# %%
df7.index
# Out:
# RangeIndex(start=0, stop=21, step=1)

# %%
df7.columns
# Out:
# Index(['Passenger_No', 'first_name', 'last_name', 'survived', 'pclass', 'sex',
#        'age', 'parch', 'fare', 'embarked', 'class', 'who', 'adult_male',
#        'deck', 'embark_town', 'alive', 'alone', 'DECK_NUMBER'],
#       dtype='object')

# %%
df7['survived'].value_counts()
# Out:
# 0    11
# 1    10
# Name: survived, dtype: int64

# %%
df7['sex'].value_counts()
# Out:
# female    11
# male      10
# Name: sex, dtype: int64

# %%
df7['class'].value_counts()
# Out:
# Third     13
# First      4
# Second     4
# Name: class, dtype: int64

# %%
df7.describe(include="all")
# Out:
#         Passenger_No first_name last_name   survived     pclass     sex  \
# count      21.000000         21        21  21.000000  21.000000      21
# unique           NaN         21        21        NaN        NaN       2
# top              NaN     Steven      King        NaN        NaN  female
# freq             NaN          1         1        NaN        NaN      11
# mean       11.000000        NaN       NaN   0.476190   2.428571     NaN
# std         6.204837        NaN       NaN   0.511766   0.810643     NaN
# min         1.000000        NaN       NaN   0.000000   1.000000     NaN
# 25%         6.000000        NaN       NaN   0.000000   2.000000     NaN
# 50%        11.000000        NaN       NaN   0.000000   3.000000     NaN
# 75%        16.000000        NaN       NaN   1.000000   3.000000     NaN
# max        21.000000        NaN       NaN   1.000000   3.000000     NaN
#
#               age      parch          fare embarked  class  who adult_male  \
# count   21.000000  21.000000     21.000000       21     21   21         21
# unique        NaN        NaN           NaN        3      3    3          2
# top           NaN        NaN           NaN        S  Third  man      False
# freq          NaN        NaN           NaN       16     13    8         13
# mean    28.619048   0.476190  43616.095238      NaN    NaN  NaN        NaN
# std     16.026466   1.167007  15081.489823      NaN    NaN  NaN        NaN
# min      2.000000   0.000000  20068.000000      NaN    NaN  NaN        NaN
# 25%     20.000000   0.000000  29047.000000      NaN    NaN  NaN        NaN
# 50%     29.000000   0.000000  46206.000000      NaN    NaN  NaN        NaN
# 75%     35.000000   0.000000  56356.000000      NaN    NaN  NaN        NaN
# max     58.000000   5.000000  66662.000000      NaN    NaN  NaN        NaN
#
#        deck  embark_town alive alone  DECK_NUMBER
# count    21           21    21    21    21.000000
# unique    6            3     2     2          NaN
# top       C  Southampton    no  True          NaN
# freq      6           16    11    11          NaN
# mean    NaN          NaN   NaN   NaN    79.047619
# std     NaN          NaN   NaN   NaN    13.749459
# min     NaN          NaN   NaN   NaN    60.000000
# 25%     NaN          NaN   NaN   NaN    70.000000
# 50%     NaN          NaN   NaN   NaN    80.000000
# 75%     NaN          NaN   NaN   NaN    90.000000
# max     NaN          NaN   NaN   NaN   100.000000

# %%
df7[df7['fare']>20000]
# Out:
#     Passenger_No first_name    last_name  survived  pclass     sex  age  \
# 0              1     Steven         King         0       3    male   22
# 1              2       Ross      Kochhar         1       1  female   38
# 2              3       Alex        Urman         1       3  female   26
# 3              4      Bruce         Popp         1       1  female   35
# 4              5      David     Raphaely         0       3    male   35
# 5              6      Nancy         Khoo         0       3    male   27
# 6              7       John        Baida         0       1    male   54
# 7              8     Daniel        Weiss         0       3    male    2
# 8              9      Sigal     Kaufling         1       3  female   27
# 9             10       Adam      Vollman         1       2  female   14
# 10            11     Mathew       Himuro         1       3  female    4
# 11            12     Harvey  Mikkilineni         1       1  female   58
# 12            13      Kevin       Rogers         0       3    male   20
# 13            14      Julia        Patel         0       3    male   39
# 14            15      Irene       Davies         0       3  female   14
# 15            16      James      Zlotkey         1       2  female   55
# 16            17      Jason    Bernstein         0       3    male    2
# 17            18      Peter         Hall         1       2    male   34
# 18            19     Sartha        Sully         0       3  female   31
# 19            20    William        Smith         1       3  female   29
# 20            21       Jack       Greene         0       2    male   35
#
#     parch   fare embarked   class    who  adult_male deck  embark_town alive  \
# 0       0  24000        S   Third    man        True    A  Southampton    no
# 1       0  50806        C   First  woman       False    C    Cherbourg   yes
# 2       0  54071        S   Third  woman       False    B  Southampton   yes
# 3       0  26969        S   First  woman       False    C  Southampton   yes
# 4       0  34048        S   Third    man        True    C  Southampton    no
# 5       0  46206        Q   Third    man        True    E   Queenstown    no
# 6       0  63090        S   First    man        True    E  Southampton    no
# 7       1  56356        S   Third  child       False    G  Southampton    no
# 8       2  23488        S   Third  woman       False    A  Southampton   yes
# 9       0  29047        C  Second  child       False    B    Cherbourg   yes
# 10      1  51428        S   Third  child       False    G  Southampton   yes
# 11      0  61770        S   First  woman       False    C  Southampton   yes
# 12      0  30897        S   Third    man        True    C  Southampton    no
# 13      5  59197        S   Third    man        True    C  Southampton    no
# 14      0  61211        S   Third  child       False    G  Southampton    no
# 15      0  43386        S  Second  woman       False    D  Southampton   yes
# 16      1  27978        Q   Third  child       False    G   Queenstown    no
# 17      0  46632        S  Second    man        True    B  Southampton   yes
# 18      0  66662        S   Third  woman       False    D  Southampton    no
# 19      0  38628        C   Third  woman       False    D    Cherbourg   yes
# 20      0  20068        S  Second    man        True    G  Southampton    no
#
#     alone  DECK_NUMBER
# 0   False           90
# 1   False           90
# 2    True           90
# 3   False           60
# 4    True           60
# 5    True           70
# 6    True           70
# 7   False           70
# 8   False           60
# 9   False           90
# 10  False          100
# 11   True          100
# 12   True           70
# 13  False           80
# 14   True           80
# 15   True           80
# 16  False          100
# 17   True           80
# 18  False           60
# 19   True           70
# 20   True           90

# %%
df7[(df7['fare']>20000) & (df7['survived']==1)]
# Out:
#     Passenger_No first_name    last_name  survived  pclass     sex  age  \
# 1              2       Ross      Kochhar         1       1  female   38
# 2              3       Alex        Urman         1       3  female   26
# 3              4      Bruce         Popp         1       1  female   35
# 8              9      Sigal     Kaufling         1       3  female   27
# 9             10       Adam      Vollman         1       2  female   14
# 10            11     Mathew       Himuro         1       3  female    4
# 11            12     Harvey  Mikkilineni         1       1  female   58
# 15            16      James      Zlotkey         1       2  female   55
# 17            18      Peter         Hall         1       2    male   34
# 19            20    William        Smith         1       3  female   29
#
#     parch   fare embarked   class    who  adult_male deck  embark_town alive  \
# 1       0  50806        C   First  woman       False    C    Cherbourg   yes
# 2       0  54071        S   Third  woman       False    B  Southampton   yes
# 3       0  26969        S   First  woman       False    C  Southampton   yes
# 8       2  23488        S   Third  woman       False    A  Southampton   yes
# 9       0  29047        C  Second  child       False    B    Cherbourg   yes
# 10      1  51428        S   Third  child       False    G  Southampton   yes
# 11      0  61770        S   First  woman       False    C  Southampton   yes
# 15      0  43386        S  Second  woman       False    D  Southampton   yes
# 17      0  46632        S  Second    man        True    B  Southampton   yes
# 19      0  38628        C   Third  woman       False    D    Cherbourg   yes
#
#     alone  DECK_NUMBER
# 1   False           90
# 2    True           90
# 3   False           60
# 8   False           60
# 9   False           90
# 10  False          100
# 11   True          100
# 15   True           80
# 17   True           80
# 19   True           70

# %%
df7[(df7['age']<30) & (df7['survived']==1)]
# Out:
#     Passenger_No first_name last_name  survived  pclass     sex  age  parch  \
# 2              3       Alex     Urman         1       3  female   26      0
# 8              9      Sigal  Kaufling         1       3  female   27      2
# 9             10       Adam   Vollman         1       2  female   14      0
# 10            11     Mathew    Himuro         1       3  female    4      1
# 19            20    William     Smith         1       3  female   29      0
#
#      fare embarked   class    who  adult_male deck  embark_town alive  alone  \
# 2   54071        S   Third  woman       False    B  Southampton   yes   True
# 8   23488        S   Third  woman       False    A  Southampton   yes  False
# 9   29047        C  Second  child       False    B    Cherbourg   yes  False
# 10  51428        S   Third  child       False    G  Southampton   yes  False
# 19  38628        C   Third  woman       False    D    Cherbourg   yes   True
#
#     DECK_NUMBER
# 2            90
# 8            60
# 9            90
# 10          100
# 19           70

# %%
df7[(df7['class']=='First') & (df7['survived']==1)]
# Out:
#     Passenger_No first_name    last_name  survived  pclass     sex  age  \
# 1              2       Ross      Kochhar         1       1  female   38
# 3              4      Bruce         Popp         1       1  female   35
# 11            12     Harvey  Mikkilineni         1       1  female   58
#
#     parch   fare embarked  class    who  adult_male deck  embark_town alive  \
# 1       0  50806        C  First  woman       False    C    Cherbourg   yes
# 3       0  26969        S  First  woman       False    C  Southampton   yes
# 11      0  61770        S  First  woman       False    C  Southampton   yes
#
#     alone  DECK_NUMBER
# 1   False           90
# 3   False           60
# 11   True          100

# %%
df7.tail(3)
# Out:
#     Passenger_No first_name last_name  survived  pclass     sex  age  parch  \
# 18            19     Sartha     Sully         0       3  female   31      0
# 19            20    William     Smith         1       3  female   29      0
# 20            21       Jack    Greene         0       2    male   35      0
#
#      fare embarked   class    who  adult_male deck  embark_town alive  alone  \
# 18  66662        S   Third  woman       False    D  Southampton    no  False
# 19  38628        C   Third  woman       False    D    Cherbourg   yes   True
# 20  20068        S  Second    man        True    G  Southampton    no   True
#
#     DECK_NUMBER
# 18           60
# 19           70
# 20           90

# %%
df7['fare'].max()
# Out:
# 66662

# %%
df7['age'].min()
# Out:
# 2

# %%
df7['age'].mean()
# Out:
# 28.61904761904762

# %%
df7['fare'].mean()
# Out:
# 43616.09523809524
